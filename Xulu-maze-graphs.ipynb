# %% [markdown]
# ### A notebook for Xulu to generate maze graphs for certain maze sequences!
#
# First let's load the database of different barrier configurations

# %%
import pandas as pd
import pickle
from hex_maze_utils import plot_hex_maze, df_lookup

# Load the database of different barrier sequences
barrier_df = pd.read_pickle('Barrier_Sequence_Databases/barrier_sequences_first1000.pkl')
display(barrier_df)
# Out:
#                                       barrier_sequence  sequence_length  \
# 0    [(37, 7, 39, 41, 14, 46, 20, 23, 30), (37, 39,...                5
# 1    [(34, 36, 37, 39, 10, 45, 14, 15, 20), (34, 37...                6
# 2                [(34, 7, 41, 11, 46, 17, 20, 28, 31)]                1
# 3    [(34, 10, 42, 12, 45, 18, 23, 25, 31), (34, 37...                6
# 4                [(39, 9, 10, 46, 21, 22, 23, 26, 30)]                1
# ..                                                 ...              ...
# 995  [(32, 34, 45, 13, 14, 15, 18, 19, 25), (32, 34...                2
# 996  [(37, 7, 40, 13, 46, 45, 18, 25, 28), (37, 7, ...                2
# 997             [(36, 10, 11, 46, 15, 21, 25, 27, 29)]                1
# 998  [(32, 8, 9, 41, 15, 20, 21, 27, 29), (32, 8, 9...                2
# 999              [(9, 44, 46, 14, 20, 25, 26, 28, 30)]                1
#
#                                    reward_path_lengths  \
# 0    [[15, 17, 21], [15, 21, 19], [15, 17, 19], [23...
# 1    [[17, 21, 19], [19, 21, 17], [19, 15, 17], [17...
# 2                                       [[23, 19, 17]]
# 3    [[15, 19, 21], [15, 19, 17], [21, 19, 15], [21...
# 4                                       [[23, 17, 17]]
# ..                                                 ...
# 995                       [[19, 17, 15], [19, 15, 17]]
# 996                       [[15, 19, 17], [17, 19, 15]]
# 997                                     [[19, 15, 21]]
# 998                       [[17, 21, 15], [17, 15, 21]]
# 999                                     [[23, 17, 17]]
#
#                                          choice_points
# 0               [{13}, {26}, {26, 13, 29}, {29}, {13}]
# 1         [{21}, {30}, {24}, {16, 24, 26}, {24}, {35}]
# 2                                               [{35}]
# 3    [{17}, {17, 26, 35}, {35}, {24}, {24, 17, 26},...
# 4                                               [{29}]
# ..                                                 ...
# 995                                       [{35}, {24}]
# 996                                       [{26}, {36}]
# 997                                             [{16}]
# 998                                       [{31}, {13}]
# 999                                             [{29}]
#
# [1000 rows x 4 columns]

# %%
# Let's get the subset of the database with sequences>= length 5
barrier_df_long_sequences = barrier_df[barrier_df['sequence_length'] >= 5]
display(barrier_df_long_sequences)
# Out:
#                                       barrier_sequence  sequence_length  \
# 0    [(37, 7, 39, 41, 14, 46, 20, 23, 30), (37, 39,...                5
# 1    [(34, 36, 37, 39, 10, 45, 14, 15, 20), (34, 37...                6
# 3    [(34, 10, 42, 12, 45, 18, 23, 25, 31), (34, 37...                6
# 9    [(34, 39, 42, 11, 12, 16, 21, 27, 30), (34, 39...                5
# 11   [(32, 37, 8, 40, 9, 11, 16, 21, 28), (32, 37, ...                5
# ..                                                 ...              ...
# 957  [(39, 9, 10, 42, 21, 22, 23, 25, 30), (39, 9, ...                5
# 958  [(34, 37, 40, 10, 11, 15, 20, 22, 26), (34, 37...                6
# 962  [(34, 39, 8, 42, 12, 46, 21, 27, 30), (34, 39,...                5
# 977  [(34, 37, 7, 41, 10, 18, 25, 28, 30), (34, 37,...                5
# 987  [(37, 8, 12, 45, 16, 21, 25, 27, 29), (37, 39,...                5
#
#                                    reward_path_lengths  \
# 0    [[15, 17, 21], [15, 21, 19], [15, 17, 19], [23...
# 1    [[17, 21, 19], [19, 21, 17], [19, 15, 17], [17...
# 3    [[15, 19, 21], [15, 19, 17], [21, 19, 15], [21...
# 9    [[17, 25, 19], [17, 15, 19], [21, 15, 19], [17...
# 11   [[19, 21, 15], [19, 17, 15], [17, 17, 23], [21...
# ..                                                 ...
# 957  [[23, 17, 17], [15, 21, 17], [15, 17, 19], [15...
# 958  [[19, 21, 17], [19, 15, 17], [19, 15, 21], [17...
# 962  [[17, 15, 19], [17, 25, 19], [21, 15, 19], [17...
# 977  [[15, 19, 21], [15, 19, 17], [21, 19, 15], [17...
# 987  [[19, 21, 15], [19, 15, 23], [19, 15, 17], [19...
#
#                                          choice_points
# 0               [{13}, {26}, {26, 13, 29}, {29}, {13}]
# 1         [{21}, {30}, {24}, {16, 24, 26}, {24}, {35}]
# 3    [{17}, {17, 26, 35}, {35}, {24}, {24, 17, 26},...
# 9               [{31}, {24, 13, 31}, {24}, {13}, {31}]
# 11              [{36}, {13, 36, 29}, {13}, {29}, {13}]
# ..                                                 ...
# 957             [{29}, {31}, {17}, {17, 29, 31}, {29}]
# 958               [{30}, {24}, {16}, {17}, {24}, {36}]
# 962             [{24, 13, 31}, {31}, {24}, {13}, {31}]
# 977     [{17}, {17, 26, 35}, {35}, {17, 35, 36}, {17}]
# 987     [{36}, {13}, {24, 36, 13}, {35, 36, 13}, {13}]
#
# [121 rows x 4 columns]

# %% [markdown]
# Now lets plot some of the mazes for a sequence.

# %%
# Let's get a sequence from the database
i = 1 # change this number to get a different sequence
barrier_sequence = barrier_df.iloc[i]['barrier_sequence']

# Print each barrier set in the sequence + the reward path lengths
print(f"The barrier sequence is:")
for index, barriers in enumerate(barrier_sequence):
    rwd_path_lengths = df_lookup(df, barriers, 'reward_path_lengths')
    print(f"Barrier set {index}: {barriers}, reward path lengths = {rwd_path_lengths}")
print("\n")
    
# Plot all of the mazes in the sequence. 
print("Now let's plot the mazes in the sequence:")
for index, barriers in enumerate(barrier_sequence):
    print(f"Barriers set {index}: {barriers}")
    plot_hex_maze(barriers)
# Out:
# The barrier sequence is:
# Barrier set 0: frozenset({34, 36, 37, 39, 10, 45, 14, 15, 20}), reward path lengths = [17, 21, 19]
# Barrier set 1: frozenset({34, 37, 39, 10, 45, 14, 15, 20, 26}), reward path lengths = [19, 21, 17]
# Barrier set 2: frozenset({34, 37, 39, 10, 45, 14, 15, 25, 26}), reward path lengths = [19, 15, 17]
# Barrier set 3: frozenset({34, 37, 39, 10, 45, 14, 15, 46, 25}), reward path lengths = [17, 15, 19]
# Barrier set 4: frozenset({34, 37, 39, 45, 46, 14, 13, 15, 25}), reward path lengths = [21, 15, 19]
# Barrier set 5: frozenset({34, 37, 45, 46, 15, 14, 13, 19, 25}), reward path lengths = [21, 17, 17]
#
#
# Now let's plot the mazes in the sequence:
# Barriers set 0: frozenset({34, 36, 37, 39, 10, 45, 14, 15, 20})
# Barriers set 1: frozenset({34, 37, 39, 10, 45, 14, 15, 20, 26})
# Barriers set 2: frozenset({34, 37, 39, 10, 45, 14, 15, 25, 26})
# Barriers set 3: frozenset({34, 37, 39, 10, 45, 14, 15, 46, 25})
# Barriers set 4: frozenset({34, 37, 39, 45, 46, 14, 13, 15, 25})
# Barriers set 5: frozenset({34, 37, 45, 46, 15, 14, 13, 19, 25})

# %%
# It's also easy to copy/paste a set of barriers to plot them using plot_hex_maze
from hex_maze_utils import plot_hex_maze

b = {34, 10, 42, 12, 45, 18, 23, 25, 31}
plot_hex_maze(b)

# %%
# If we want the database of info about different mazes, here is that also
df = pd.read_pickle('maze_configuration_database.pkl')
display(df)
# Out:
#                                    barriers  len12  len13  len23  \
# 0       (37, 39, 7, 41, 14, 46, 20, 23, 30)     15     17     21
# 1      (34, 36, 37, 39, 10, 45, 14, 15, 20)     17     21     19
# 2       (34, 7, 41, 11, 46, 17, 20, 28, 31)     23     19     17
# 3      (34, 10, 42, 12, 45, 18, 23, 25, 31)     15     19     21
# 4       (39, 9, 10, 46, 21, 22, 23, 26, 30)     23     17     17
# ...                                     ...    ...    ...    ...
# 55891   (34, 36, 7, 10, 42, 46, 19, 22, 25)     15     19     21
# 55892    (37, 7, 9, 13, 45, 16, 22, 25, 29)     17     19     15
# 55893   (7, 39, 46, 17, 19, 22, 23, 24, 30)     17     23     17
# 55894  (34, 10, 11, 42, 45, 15, 22, 25, 30)     17     15     19
# 55895   (32, 37, 8, 45, 15, 20, 21, 27, 29)     19     21     15
#
#       reward_path_lengths  path_length_difference  \
# 0            [15, 17, 21]                       6
# 1            [17, 21, 19]                       4
# 2            [23, 19, 17]                       6
# 3            [15, 19, 21]                       6
# 4            [23, 17, 17]                       6
# ...                   ...                     ...
# 55891        [15, 19, 21]                       6
# 55892        [17, 19, 15]                       4
# 55893        [17, 23, 17]                       6
# 55894        [17, 15, 19]                       4
# 55895        [19, 21, 15]                       6
#
#                                         optimal_paths_12  \
# 0      [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3      [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# ...                                                  ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...
# 55894  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
#
#                                         optimal_paths_13  \
# 0      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 25, 30, 3...
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# ...                                                  ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 30, ...
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...
# 55894  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
#
#                                         optimal_paths_23  \
# 0      [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 1...
# 1      [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 2...
# 2      [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 4...
# 3      [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 4      [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# ...                                                  ...
# 55891  [[2, 49, 38, 32, 37, 31, 26, 21, 17, 13, 16, 2...
# 55892  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 40, 44, 3...
# 55893  [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 55894  [[2, 49, 38, 32, 37, 31, 26, 21, 17, 13, 16, 2...
# 55895  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 40, 44, 3...
#
#                                        optimal_paths_all choice_points  \
# 0      [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...          {13}
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {21}
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...          {35}
# 3      [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...          {17}
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...          {29}
# ...                                                  ...           ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...          {17}
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...          {36}
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...          {31}
# 55894  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...          {16}
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...          {36}
#
#        num_choice_points                                             cycles  \
# 0                      1                                                 []
# 1                      1                                                 []
# 2                      1                         [[38, 49, 47, 42, 37, 32]]
# 3                      1                                                 []
# 4                      1  [[32, 38, 49, 47, 42, 37], [12, 15, 19, 24, 20...
# ...                  ...                                                ...
# 55891                  1                                                 []
# 55892                  1                         [[34, 28, 33, 48, 43, 39]]
# 55893                  1                         [[32, 38, 49, 47, 42, 37]]
# 55894                  1  [[19, 23, 28, 33, 48, 43, 39, 44, 40, 35, 29, ...
# 55895                  1  [[10, 13, 16, 12, 9, 7], [34, 28, 33, 48, 43, ...
#
#        num_cycles                                   isomorphic_mazes
# 0               0  {(37, 8, 9, 40, 20, 21, 22, 27, 28), (34, 8, 4...
# 1               0  {(34, 37, 8, 40, 10, 15, 18, 20, 26), (34, 35,...
# 2               1  {(35, 7, 10, 44, 20, 22, 27, 28, 31), (32, 37,...
# 3               0  {(34, 37, 8, 40, 13, 46, 15, 18, 25), (34, 37,...
# 4               2  {(34, 36, 8, 41, 9, 21, 23, 27, 30), (10, 11, ...
# ...           ...                                                ...
# 55891           0  {(34, 37, 7, 40, 9, 42, 14, 16, 25), (35, 37, ...
# 55892           1  {(32, 34, 40, 13, 15, 25, 26, 27, 31), (36, 10...
# 55893           1  {(32, 36, 7, 40, 11, 14, 17, 20, 23), (32, 36,...
# 55894           1  {(34, 37, 8, 12, 45, 18, 21, 23, 25), (37, 40,...
# 55895           2  {(37, 39, 42, 13, 46, 15, 18, 20, 30), (34, 7,...
#
# [55896 rows x 15 columns]
