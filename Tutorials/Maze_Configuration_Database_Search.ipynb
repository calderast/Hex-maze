# %% [markdown]
# # Tutorial notebook on how to search the database for the maze configuration we want

# %%
import pickle
import pandas as pd
import numpy as np
import sys
sys.path.append("..")  # Use sys to add the parent directory (where hex_maze_utils lives) to the path

# %% [markdown]
# ## 1. Load the database

# %%
df = pd.read_pickle('../Maze_Databases/maze_configuration_database.pkl')
display(df)
# Out:
#                                    barriers  len12  len13  len23  \
# 0       (37, 39, 7, 41, 14, 46, 20, 23, 30)     15     17     21
# 1      (34, 36, 37, 39, 10, 45, 14, 15, 20)     17     21     19
# 2       (34, 7, 41, 11, 46, 17, 20, 28, 31)     23     19     17
# 3      (34, 10, 42, 12, 45, 18, 23, 25, 31)     15     19     21
# 4       (39, 9, 10, 46, 21, 22, 23, 26, 30)     23     17     17
# ...                                     ...    ...    ...    ...
# 55891   (34, 36, 7, 10, 42, 46, 19, 22, 25)     15     19     21
# 55892    (37, 7, 9, 13, 45, 16, 22, 25, 29)     17     19     15
# 55893   (7, 39, 46, 17, 19, 22, 23, 24, 30)     17     23     17
# 55894  (34, 10, 11, 42, 45, 15, 22, 25, 30)     17     15     19
# 55895   (32, 37, 8, 45, 15, 20, 21, 27, 29)     19     21     15
#
#       reward_path_lengths  path_length_difference  \
# 0            [15, 17, 21]                       6
# 1            [17, 21, 19]                       4
# 2            [23, 19, 17]                       6
# 3            [15, 19, 21]                       6
# 4            [23, 17, 17]                       6
# ...                   ...                     ...
# 55891        [15, 19, 21]                       6
# 55892        [17, 19, 15]                       4
# 55893        [17, 23, 17]                       6
# 55894        [17, 15, 19]                       4
# 55895        [19, 21, 15]                       6
#
#                                         optimal_paths_12  \
# 0      [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3      [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# ...                                                  ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...
# 55894  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
#
#                                         optimal_paths_13  \
# 0      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 25, 30, 3...
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# ...                                                  ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 30, ...
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...
# 55894  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
#
#                                         optimal_paths_23  \
# 0      [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 1...
# 1      [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 2...
# 2      [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 4...
# 3      [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 4      [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# ...                                                  ...
# 55891  [[2, 49, 38, 32, 37, 31, 26, 21, 17, 13, 16, 2...
# 55892  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 40, 44, 3...
# 55893  [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 55894  [[2, 49, 38, 32, 37, 31, 26, 21, 17, 13, 16, 2...
# 55895  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 40, 44, 3...
#
#                                        optimal_paths_all choice_points  \
# 0      [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...          {13}
# 1      [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {21}
# 2      [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...          {35}
# 3      [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...          {17}
# 4      [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...          {29}
# ...                                                  ...           ...
# 55891  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...          {17}
# 55892  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...          {36}
# 55893  [[1, 4, 6, 8, 10, 13, 16, 20, 25, 21, 26, 31, ...          {31}
# 55894  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...          {16}
# 55895  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...          {36}
#
#        num_choice_points                                             cycles  \
# 0                      1                                                 []
# 1                      1                                                 []
# 2                      1                         [[38, 49, 47, 42, 37, 32]]
# 3                      1                                                 []
# 4                      1  [[32, 38, 49, 47, 42, 37], [12, 15, 19, 24, 20...
# ...                  ...                                                ...
# 55891                  1                                                 []
# 55892                  1                         [[34, 28, 33, 48, 43, 39]]
# 55893                  1                         [[32, 38, 49, 47, 42, 37]]
# 55894                  1  [[19, 23, 28, 33, 48, 43, 39, 44, 40, 35, 29, ...
# 55895                  1  [[10, 13, 16, 12, 9, 7], [34, 28, 33, 48, 43, ...
#
#        num_cycles                                   isomorphic_mazes
# 0               0  {(37, 8, 9, 40, 20, 21, 22, 27, 28), (34, 8, 4...
# 1               0  {(34, 37, 8, 40, 10, 15, 18, 20, 26), (34, 35,...
# 2               1  {(35, 7, 10, 44, 20, 22, 27, 28, 31), (32, 37,...
# 3               0  {(34, 37, 8, 40, 13, 46, 15, 18, 25), (34, 37,...
# 4               2  {(34, 36, 8, 41, 9, 21, 23, 27, 30), (10, 11, ...
# ...           ...                                                ...
# 55891           0  {(34, 37, 7, 40, 9, 42, 14, 16, 25), (35, 37, ...
# 55892           1  {(32, 34, 40, 13, 15, 25, 26, 27, 31), (36, 10...
# 55893           1  {(32, 36, 7, 40, 11, 14, 17, 20, 23), (32, 36,...
# 55894           1  {(34, 37, 8, 12, 45, 18, 21, 23, 25), (37, 40,...
# 55895           2  {(37, 39, 42, 13, 46, 15, 18, 20, 30), (34, 7,...
#
# [55896 rows x 15 columns]

# %% [markdown]
# ## 2. Get a subset of the database including only mazes with certain attributes
# Often, we use lambda expressions to compare each row to a specific criteria.

# %% [markdown]
# #### Here's how to filter the database in different ways to find mazes with specifc choice points.

# %%
# For example, I want only mazes with 3 choice points
filtered = df[(df['num_choice_points'] == 3)]
print(f"There are {len(filtered)} mazes with exactly 3 choice points:")
display(filtered.head())

# Now I want only mazes with 3 specific choice points: 21, 20 and 16
filtered = df[(df['choice_points'] == {21, 20, 16})]
print(f"There are {len(filtered)} mazes with 21, 20 and 16 as the 3 choice points:")
display(filtered.head())

# Now I want mazes with 16 as the ONLY choice point
filtered = df[(df['choice_points'] == {16})]
print(f"There are {len(filtered)} mazes where hex 16 is the only choice point:")
display(filtered.head())

# Or mazes with 16 as a choice point, but it's ok if there are other choice points too
filtered = df[df['choice_points'].apply(lambda x: 16 in x)]
print(f"There are {len(filtered)} mazes where hex 16 is one of the choice points:")
display(filtered.head())
# Out:
# There are 1692 mazes with exactly 3 choice points:
#                                  barriers  len12  len13  len23  \
# 13    (34, 36, 9, 10, 42, 46, 22, 23, 30)     15     19     19
# 106   (7, 42, 10, 44, 20, 22, 27, 28, 30)     15     19     17
# 150  (37, 39, 10, 45, 14, 18, 19, 27, 30)     19     15     19
# 151   (32, 37, 8, 40, 10, 44, 20, 24, 28)     19     19     15
# 200   (37, 9, 10, 44, 45, 20, 22, 25, 28)     17     19     15
#
#     reward_path_lengths  path_length_difference  \
# 13         [15, 19, 19]                       4
# 106        [15, 19, 17]                       4
# 150        [19, 15, 19]                       4
# 151        [19, 19, 15]                       4
# 200        [17, 19, 15]                       4
#
#                                       optimal_paths_12  \
# 13   [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...
# 106  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...
# 150  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 151  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 200  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
#
#                                       optimal_paths_13  \
# 13   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 106  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
# 150  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 34, 28, 3...
# 151  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 25, 30, 3...
# 200  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
#
#                                       optimal_paths_23  \
# 13   [[2, 49, 38, 32, 37, 31, 26, 21, 25, 20, 24, 2...
# 106  [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 150  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 151  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 29, 34, 3...
# 200  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 29, 34, 3...
#
#                                      optimal_paths_all choice_points  \
# 13   [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...  {17, 20, 21}
# 106  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 37, 32, ...  {17, 29, 31}
# 150  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
# 151  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {36, 21, 30}
# 200  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...  {17, 36, 29}
#
#      num_choice_points                                             cycles  \
# 13                   3  [[16, 12, 15, 19, 24, 20], [13, 16, 20, 25, 21...
# 106                  3  [[13, 16, 12, 15, 19, 24, 29, 35, 40, 45, 41, ...
# 150                  3                         [[13, 17, 21, 25, 20, 16]]
# 151                  3  [[26, 31, 36, 30, 25, 21], [14, 18, 22, 26, 21...
# 200                  3  [[13, 16, 12, 15, 19, 24, 29, 35, 30, 36, 31, ...
#
#      num_cycles                                   isomorphic_mazes
# 13            2  {(32, 34, 41, 10, 9, 21, 23, 26, 27), (35, 37,...
# 106           1  {(32, 39, 8, 10, 46, 19, 21, 23, 30), (32, 34,...
# 150           1  {(34, 37, 8, 40, 12, 45, 46, 18, 21), (34, 10,...
# 151           2  {(32, 34, 7, 41, 10, 46, 21, 26, 28), (34, 37,...
# 200           1  {(32, 34, 10, 11, 45, 46, 19, 21, 25), (34, 37...
# There are 161 mazes with 21, 20 and 16 as the 3 choice points:
#                                   barriers  len12  len13  len23  \
# 150   (37, 39, 10, 45, 14, 18, 19, 27, 30)     19     15     19
# 370    (32, 35, 37, 39, 8, 10, 44, 19, 30)     19     15     19
# 867   (35, 37, 39, 10, 44, 14, 19, 27, 30)     19     15     19
# 1498  (32, 35, 37, 39, 10, 11, 18, 19, 30)     19     15     19
# 1780  (32, 34, 37, 10, 45, 14, 19, 23, 30)     19     17     21
#
#      reward_path_lengths  path_length_difference  \
# 150         [19, 15, 19]                       4
# 370         [19, 15, 19]                       4
# 867         [19, 15, 19]                       4
# 1498        [19, 15, 19]                       4
# 1780        [19, 17, 21]                       4
#
#                                        optimal_paths_12  \
# 150   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 370   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 867   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 1498  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 1780  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
#
#                                        optimal_paths_13  \
# 150   [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 34, 28, 3...
# 370   [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 34, 28, 3...
# 867   [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 34, 28, 3...
# 1498  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 34, 28, 3...
# 1780  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 35, 40, 4...
#
#                                        optimal_paths_23  \
# 150   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 370   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 867   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1498  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1780  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
#
#                                       optimal_paths_all choice_points  \
# 150   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
# 370   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
# 867   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
# 1498  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
# 1780  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {16, 20, 21}
#
#       num_choice_points                                             cycles  \
# 150                   3                         [[13, 17, 21, 25, 20, 16]]
# 370                   3  [[17, 14, 18, 22, 26, 21], [13, 17, 21, 25, 20...
# 867                   3                         [[13, 17, 21, 25, 20, 16]]
# 1498                  3                         [[13, 17, 21, 25, 20, 16]]
# 1780                  3                         [[13, 17, 21, 25, 20, 16]]
#
#       num_cycles                                   isomorphic_mazes
# 150            1  {(34, 37, 8, 40, 12, 45, 46, 18, 21), (34, 10,...
# 370            2  {(32, 37, 8, 40, 10, 20, 23, 24, 28), (34, 36,...
# 867            1  {(34, 37, 8, 40, 11, 12, 46, 17, 21), (32, 34,...
# 1498           1  {(34, 37, 39, 7, 45, 46, 14, 16, 20), (34, 36,...
# 1780           1  {(34, 37, 7, 41, 10, 46, 18, 19, 21), (34, 37,...
# There are 4601 mazes where hex 16 is the only choice point:
#                                 barriers  len12  len13  len23  \
# 19  (34, 37, 40, 10, 46, 15, 14, 25, 30)     17     15     19
# 23   (8, 10, 11, 44, 14, 15, 25, 29, 31)     17     15     19
# 30   (35, 39, 8, 10, 42, 44, 15, 18, 25)     17     15     19
# 51  (36, 37, 39, 10, 44, 14, 15, 25, 29)     17     15     19
# 84   (39, 8, 10, 45, 15, 21, 25, 27, 29)     19     15     21
#
#    reward_path_lengths  path_length_difference  \
# 19        [17, 15, 19]                       4
# 23        [17, 15, 19]                       4
# 30        [17, 15, 19]                       4
# 51        [17, 15, 19]                       4
# 84        [19, 15, 21]                       6
#
#                                      optimal_paths_12  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 23  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 30  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 51  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 84  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...
#
#                                      optimal_paths_13  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 23  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 30  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 51  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 84  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
#
#                                      optimal_paths_23  \
# 19  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 23  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 30  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 51  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 84  [[2, 49, 38, 32, 37, 31, 26, 22, 18, 14, 17, 1...
#
#                                     optimal_paths_all choice_points  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 23  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 30  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 51  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 84  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...          {16}
#
#     num_choice_points                                             cycles  \
# 19                  1                                                 []
# 23                  1  [[34, 39, 43, 48, 33, 28], [38, 49, 47, 42, 37...
# 30                  1  [[19, 23, 28, 34, 29, 24], [22, 27, 32, 37, 31...
# 51                  1                                                 []
# 84                  1  [[37, 42, 46, 41, 36, 31], [37, 32, 38, 49, 47...
#
#     num_cycles                                   isomorphic_mazes
# 19           0  {(34, 37, 41, 10, 12, 18, 20, 23, 25), (34, 37...
# 23           3  {(7, 9, 10, 12, 46, 18, 25, 29, 31), (34, 39, ...
# 30           2  {(37, 7, 9, 42, 45, 16, 18, 25, 28), (32, 37, ...
# 51           0  {(34, 37, 8, 40, 11, 13, 15, 25, 26), (34, 37,...
# 84           2  {(32, 37, 11, 45, 15, 21, 25, 28, 29), (32, 34...
# There are 5018 mazes where hex 16 is one of the choice points:
#                                 barriers  len12  len13  len23  \
# 19  (34, 37, 40, 10, 46, 15, 14, 25, 30)     17     15     19
# 23   (8, 10, 11, 44, 14, 15, 25, 29, 31)     17     15     19
# 30   (35, 39, 8, 10, 42, 44, 15, 18, 25)     17     15     19
# 51  (36, 37, 39, 10, 44, 14, 15, 25, 29)     17     15     19
# 84   (39, 8, 10, 45, 15, 21, 25, 27, 29)     19     15     21
#
#    reward_path_lengths  path_length_difference  \
# 19        [17, 15, 19]                       4
# 23        [17, 15, 19]                       4
# 30        [17, 15, 19]                       4
# 51        [17, 15, 19]                       4
# 84        [19, 15, 21]                       6
#
#                                      optimal_paths_12  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 23  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 30  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 51  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 84  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...
#
#                                      optimal_paths_13  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 23  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 30  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 51  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
# 84  [[1, 4, 5, 7, 9, 12, 16, 20, 24, 19, 23, 28, 3...
#
#                                      optimal_paths_23  \
# 19  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 23  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 30  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 51  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 84  [[2, 49, 38, 32, 37, 31, 26, 22, 18, 14, 17, 1...
#
#                                     optimal_paths_all choice_points  \
# 19  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 23  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 30  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 51  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {16}
# 84  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...          {16}
#
#     num_choice_points                                             cycles  \
# 19                  1                                                 []
# 23                  1  [[34, 39, 43, 48, 33, 28], [38, 49, 47, 42, 37...
# 30                  1  [[19, 23, 28, 34, 29, 24], [22, 27, 32, 37, 31...
# 51                  1                                                 []
# 84                  1  [[37, 42, 46, 41, 36, 31], [37, 32, 38, 49, 47...
#
#     num_cycles                                   isomorphic_mazes
# 19           0  {(34, 37, 41, 10, 12, 18, 20, 23, 25), (34, 37...
# 23           3  {(7, 9, 10, 12, 46, 18, 25, 29, 31), (34, 39, ...
# 30           2  {(37, 7, 9, 42, 45, 16, 18, 25, 28), (32, 37, ...
# 51           0  {(34, 37, 8, 40, 11, 13, 15, 25, 26), (34, 37,...
# 84           2  {(32, 37, 11, 45, 15, 21, 25, 28, 29), (32, 34...

# %% [markdown]
# #### Here's how to filter the database in different ways for mazes with different reward path lengths.

# %%
# For example, I want only mazes with reward path lengths 17, 19, and 21 (in that specific order)
filtered = df[df['reward_path_lengths'].apply(lambda x: x == [17, 19, 21])]
print(f"There are {len(filtered)} mazes with path lengths 17, 19, 21, with length 17 between ports 1 and 2, 19 between 1 and 3, and 21 between 2 and 3:")
display(filtered.head())

# Now I want mazes with reward path lengths 17, 19, and 21 in any order
filtered = df[df['reward_path_lengths'].apply(lambda x: set([17, 19, 21]).issubset(x))]
print(f"There are {len(filtered)} mazes with path lengths 17, 19, 21 in any order:")
display(filtered.head())
# Out:
# There are 160 mazes with path lengths 17, 19, 21, with length 17 between ports 1 and 2, 19 between 1 and 3, and 21 between 2 and 3:
#                                  barriers  len12  len13  len23  \
# 599   (34, 37, 9, 45, 13, 18, 19, 27, 30)     17     19     21
# 1330  (34, 37, 9, 10, 45, 18, 22, 28, 30)     17     19     21
# 1768  (34, 37, 9, 10, 45, 19, 22, 27, 30)     17     19     21
# 1843  (32, 34, 37, 7, 45, 14, 16, 23, 30)     17     19     21
# 1901   (34, 37, 7, 9, 10, 45, 19, 22, 30)     17     19     21
#
#      reward_path_lengths  path_length_difference  \
# 599         [17, 19, 21]                       4
# 1330        [17, 19, 21]                       4
# 1768        [17, 19, 21]                       4
# 1843        [17, 19, 21]                       4
# 1901        [17, 19, 21]                       4
#
#                                        optimal_paths_12  \
# 599   [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
# 1330  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
# 1768  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
# 1843  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 31, 36, 41, ...
# 1901  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...
#
#                                        optimal_paths_13  \
# 599   [[1, 4, 6, 8, 11, 14, 17, 21, 25, 20, 24, 29, ...
# 1330  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 1768  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 1843  [[1, 4, 6, 8, 10, 13, 17, 21, 25, 20, 24, 29, ...
# 1901  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
#
#                                        optimal_paths_23  \
# 599   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1330  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1768  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1843  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 1901  [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
#
#                                       optimal_paths_all choice_points  \
# 599   [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...          {21}
# 1330  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...  {17, 20, 21}
# 1768  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...  {17, 20, 21}
# 1843  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 31, 36, 41, ...          {21}
# 1901  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 31, 36, 41, ...  {17, 20, 21}
#
#       num_choice_points                                             cycles  \
# 599                   1                              [[5, 7, 10, 8, 6, 4]]
# 1330                  3  [[16, 12, 15, 19, 24, 20], [13, 16, 20, 25, 21...
# 1768                  3                         [[13, 16, 20, 25, 21, 17]]
# 1843                  1                                                 []
# 1901                  3                         [[13, 16, 20, 25, 21, 17]]
#
#       num_cycles                                   isomorphic_mazes
# 599            1  {(34, 10, 44, 45, 14, 15, 20, 27, 31), (34, 40...
# 1330           2  {(34, 37, 40, 8, 10, 45, 15, 20, 27), (34, 37,...
# 1768           1  {(34, 37, 41, 10, 12, 46, 18, 21, 23), (34, 37...
# 1843           0  {(34, 37, 8, 12, 45, 17, 27, 28, 30), (32, 34,...
# 1901           1  {(32, 34, 37, 40, 10, 14, 15, 20, 27), (34, 37...
# There are 960 mazes with path lengths 17, 19, 21 in any order:
#                                  barriers  len12  len13  len23  \
# 1    (34, 36, 37, 39, 10, 45, 14, 15, 20)     17     21     19
# 15    (34, 37, 8, 45, 15, 17, 27, 28, 30)     19     17     21
# 70   (32, 34, 37, 13, 14, 45, 17, 19, 30)     19     17     21
# 231  (34, 37, 39, 10, 11, 45, 15, 20, 22)     19     21     17
# 262   (34, 37, 41, 10, 9, 12, 44, 18, 21)     21     17     19
#
#     reward_path_lengths  path_length_difference  \
# 1          [17, 21, 19]                       4
# 15         [19, 17, 21]                       4
# 70         [19, 17, 21]                       4
# 231        [19, 21, 17]                       4
# 262        [21, 17, 19]                       4
#
#                                       optimal_paths_12  \
# 1    [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...
# 15   [[1, 4, 5, 7, 10, 13, 16, 20, 25, 21, 26, 31, ...
# 70   [[1, 4, 5, 7, 9, 12, 16, 20, 25, 21, 26, 31, 3...
# 231  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...
# 262  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 25, 30, ...
#
#                                       optimal_paths_13  \
# 1    [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 25, 30, 3...
# 15   [[1, 4, 5, 7, 10, 13, 16, 20, 24, 29, 35, 40, ...
# 70   [[1, 4, 5, 7, 9, 12, 16, 20, 24, 29, 35, 40, 4...
# 231  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 25, 30, 3...
# 262  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 19, ...
#
#                                       optimal_paths_23  \
# 1    [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 2...
# 15   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 70   [[2, 49, 47, 42, 46, 41, 36, 31, 26, 21, 25, 2...
# 231  [[2, 49, 47, 42, 46, 41, 36, 30, 35, 29, 24, 1...
# 262  [[2, 49, 38, 32, 27, 22, 26, 31, 36, 30, 25, 2...
#
#                                      optimal_paths_all choice_points  \
# 1    [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 22, 2...          {21}
# 15   [[1, 4, 5, 7, 10, 13, 16, 20, 25, 21, 26, 31, ...          {20}
# 70   [[1, 4, 5, 7, 9, 12, 16, 20, 25, 21, 26, 31, 3...          {20}
# 231  [[1, 4, 5, 7, 9, 12, 16, 13, 17, 21, 26, 31, 3...  {36, 21, 30}
# 262  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 25, 30, ...  {24, 20, 30}
#
#      num_choice_points                      cycles  num_cycles  \
# 1                    1                          []           0
# 15                   1    [[10, 13, 16, 12, 9, 7]]           1
# 70                   1       [[5, 7, 10, 8, 6, 4]]           1
# 231                  3  [[26, 31, 36, 30, 25, 21]]           1
# 262                  3  [[25, 30, 35, 29, 24, 20]]           1
#
#                                       isomorphic_mazes
# 1    {(34, 37, 8, 40, 10, 15, 18, 20, 26), (34, 35,...
# 15   {(34, 36, 8, 10, 42, 44, 15, 18, 20), (37, 9, ...
# 70   {(34, 37, 12, 45, 13, 16, 22, 28, 30), (34, 8,...
# 231  {(34, 37, 10, 45, 14, 15, 27, 28, 30), (34, 37...
# 262  {(34, 37, 41, 10, 12, 46, 18, 21, 23), (34, 37...

# %% [markdown]
# #### Here's how to filter based on multiple criteria.

# %%
# I want to find the maximum path length difference in the database
max_path_length_diff = df['path_length_difference'].max()
print(f"The maximum path length difference is {max_path_length_diff}.")

# I only want mazes with this maximum path length difference and a single choice point
filtered = df[(df['path_length_difference'] == max_path_length_diff) & (df['num_choice_points'] == 1)]
print(f"There are {len(filtered)} mazes with path length difference {max_path_length_diff} and exactly one choice point:")
display(filtered.head())

# Let's loosen the criteria a bit - I want mazes with a path length difference of at least 6 and a single choice point
filtered = df[(df['path_length_difference'] >= 6) & (df['num_choice_points'] == 1)]
print(f"There are {len(filtered)} mazes with path length difference >= 6 and exactly one choice point:")
display(filtered.head())
# Out:
# The maximum path length difference is 8.
# There are 1548 mazes with path length difference 8 and exactly one choice point:
#                                  barriers  len12  len13  len23  \
# 9    (34, 39, 42, 11, 12, 16, 21, 27, 30)     17     25     19
# 14   (10, 11, 44, 46, 19, 21, 24, 27, 30)     19     25     17
# 18    (7, 39, 10, 42, 18, 20, 23, 26, 30)     25     19     17
# 82    (7, 10, 44, 46, 18, 20, 26, 28, 30)     25     19     17
# 127   (34, 7, 41, 11, 18, 20, 23, 25, 31)     15     19     23
#
#     reward_path_lengths  path_length_difference  \
# 9          [17, 25, 19]                       8
# 14         [19, 25, 17]                       8
# 18         [25, 19, 17]                       8
# 82         [25, 19, 17]                       8
# 127        [15, 19, 23]                       8
#
#                                       optimal_paths_12  \
# 9    [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
# 14   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...
# 18   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
# 82   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
# 127  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...
#
#                                       optimal_paths_13  \
# 9    [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
# 14   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...
# 18   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
# 82   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...
# 127  [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
#
#                                       optimal_paths_23  \
# 9    [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 14   [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 18   [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 82   [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 127  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 1...
#
#                                      optimal_paths_all choice_points  \
# 9    [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...          {31}
# 14   [[1, 4, 5, 7, 9, 12, 16, 13, 17, 14, 18, 22, 2...          {31}
# 18   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...          {29}
# 82   [[1, 4, 6, 8, 11, 14, 17, 13, 16, 12, 15, 19, ...          {29}
# 127  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...          {13}
#
#      num_choice_points                                             cycles  \
# 9                    1                              [[5, 7, 10, 8, 6, 4]]
# 14                   1  [[28, 33, 48, 43, 39, 34], [32, 38, 49, 47, 42...
# 18                   1                                                 []
# 82                   1                         [[32, 38, 49, 47, 42, 37]]
# 127                  1                         [[38, 49, 47, 42, 37, 32]]
#
#      num_cycles                                   isomorphic_mazes
# 9             1  {(7, 10, 44, 46, 20, 22, 26, 28, 30), (34, 36,...
# 14            2  {(9, 10, 44, 46, 20, 22, 23, 26, 30), (37, 9, ...
# 18            0  {(39, 8, 42, 10, 15, 21, 24, 27, 30), (32, 34,...
# 82            1  {(32, 35, 37, 8, 9, 45, 20, 21, 23), (34, 39, ...
# 127           1  {(37, 8, 9, 40, 15, 21, 25, 27, 29), (9, 10, 4...
# There are 37674 mazes with path length difference >= 6 and exactly one choice point:
#                                barriers  len12  len13  len23  \
# 0   (37, 39, 7, 41, 14, 46, 20, 23, 30)     15     17     21
# 2   (34, 7, 41, 11, 46, 17, 20, 28, 31)     23     19     17
# 3  (34, 10, 42, 12, 45, 18, 23, 25, 31)     15     19     21
# 4   (39, 9, 10, 46, 21, 22, 23, 26, 30)     23     17     17
# 5    (32, 36, 8, 9, 41, 44, 21, 23, 24)     17     17     23
#
#   reward_path_lengths  path_length_difference  \
# 0        [15, 17, 21]                       6
# 2        [23, 19, 17]                       6
# 3        [15, 19, 21]                       6
# 4        [23, 17, 17]                       6
# 5        [17, 17, 23]                       6
#
#                                     optimal_paths_12  \
# 0  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...
# 2  [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...
# 4  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 5  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...
#
#                                     optimal_paths_13  \
# 0  [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 2  [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...
# 3  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 4  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...
# 5  [[1, 4, 5, 7, 10, 13, 16, 20, 25, 30, 35, 29, ...
#
#                                     optimal_paths_23  \
# 0  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 1...
# 2  [[2, 49, 38, 32, 27, 22, 26, 21, 25, 30, 35, 4...
# 3  [[2, 49, 38, 32, 27, 22, 26, 21, 17, 13, 16, 2...
# 4  [[2, 49, 38, 32, 37, 31, 36, 41, 45, 40, 35, 2...
# 5  [[2, 49, 47, 42, 37, 31, 26, 22, 18, 14, 17, 1...
#
#                                    optimal_paths_all choice_points  \
# 0  [[1, 4, 6, 8, 10, 13, 17, 21, 26, 22, 27, 32, ...          {13}
# 2  [[1, 4, 6, 8, 10, 13, 16, 12, 15, 19, 24, 29, ...          {35}
# 3  [[1, 4, 6, 8, 11, 14, 17, 21, 26, 22, 27, 32, ...          {17}
# 4  [[1, 4, 6, 8, 11, 14, 17, 13, 16, 20, 24, 29, ...          {29}
# 5  [[1, 4, 5, 7, 10, 13, 17, 14, 18, 22, 26, 31, ...          {13}
#
#    num_choice_points                                             cycles  \
# 0                  1                                                 []
# 2                  1                         [[38, 49, 47, 42, 37, 32]]
# 3                  1                                                 []
# 4                  1  [[32, 38, 49, 47, 42, 37], [12, 15, 19, 24, 20...
# 5                  1                         [[28, 33, 48, 43, 39, 34]]
#
#    num_cycles                                   isomorphic_mazes
# 0           0  {(37, 8, 9, 40, 20, 21, 22, 27, 28), (34, 8, 4...
# 2           1  {(35, 7, 10, 44, 20, 22, 27, 28, 31), (32, 37,...
# 3           0  {(34, 37, 8, 40, 13, 46, 15, 18, 25), (34, 37,...
# 4           2  {(34, 36, 8, 41, 9, 21, 23, 27, 30), (10, 11, ...
# 5           1  {(32, 35, 8, 12, 44, 46, 16, 21, 23), (39, 9, ...

# %% [markdown]
# ## 3. Use the database to look up info about a maze

# %%
# Import our function for df lookup
from hex_maze_utils import df_lookup

# View the documentation for this function
help(df_lookup)
# Out:
# Help on function df_lookup in module hex_maze_utils:
#
# df_lookup(df, barriers, attribute_name)
#     Use the dataframe to look up a specified attribute of a barrier set.
#
#     Args:
#     df (DataFrame): The hex maze database
#     barriers (set/frozenset): A set of barriers defining a hex maze
#     attribute_name (String): The maze attribute to look up in the df.
#     Must exist as a column in the df
#
#     Returns:
#     The value of the attribute for this maze, or None if the maze isn't in the df

# %%
# Example hex maze
example_maze = {32, 36, 8, 9, 41, 44, 21, 23, 24}

# Use the database to look up the choice points for this maze
choice_points = df_lookup(df, example_maze, 'choice_points')
print(f"The choice points for this maze are {choice_points}.")

# Use the database to look up the other mazes isomorphic to this maze
isomorphic_mazes = df_lookup(df, example_maze, 'isomorphic_mazes')
print(f"The isomorphic mazes for this maze are: {isomorphic_mazes}.")
# Out:
# The choice points for this maze are {13}.
# The isomorphic mazes for this maze are: {frozenset({32, 35, 8, 12, 44, 46, 16, np.int64(21), 23}), frozenset({39, 9, 42, 11, 17, 19, 24, 27, 30}), frozenset({36, 7, 44, 46, 14, 17, 20, 27, 28}), frozenset({35, 7, 40, 11, 46, 20, 26, 27, 28}), frozenset({39, 9, 42, 11, 16, 22, 23, 26, 30})}.
